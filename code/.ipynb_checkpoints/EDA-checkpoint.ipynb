# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# %config InlineBackend.figure_format ='retina'
plt.style.use('fivethirtyeight')

# %% [markdown]
# ### Load and Read Data

# %%
#loading data collected from spotify api 
df = pd.read_csv('../data/top200-original.csv')

# %%
df.head(1)
# Out:
#    Position                                     Track Name       Artist  \
# 0       1.0  Sunflower - Spider-Man: Into the Spider-Verse  Post Malone
#
#      Streams        date region              spotify_id
# 0  1867789.0  2019-01-01     us  3KkXRkHbMCARz0aVfEt68P

# %%
df.shape
# Out:
# (730000, 7)

# %%
df.region.value_counts()
# Out:
# br            73000
# us            73000
# ca            73000
# au            73000
# de            73000
# fr            73000
# nl            73000
# gb            73000
# se            73000
# mx            72800
# 2019-04-13      200
# Name: region, dtype: int64

# %%
# Look into data type 
df.dtypes
# Out:
# Position      float64
# Track Name     object
# Artist         object
# Streams       float64
# date           object
# region         object
# spotify_id     object
# dtype: object

# %%
# Checking for missing data
df.isnull().sum()
# Out:
# Position      200
# Track Name    243
# Artist        243
# Streams       200
# date            0
# region          0
# spotify_id    201
# dtype: int64

# %% [markdown]
# ### Data Cleaning

# %%
df.dropna(axis = 0, inplace = True) # dropping null values

# %%
#converting position to a discrete value 
df['Position'] = df['Position'].apply(np.int64)

# %%
# renaming region column values 
df['region'] = df['region'].replace('au', 'Australia')
df['region'] = df['region'].replace('br', 'Brazil')
df['region'] = df['region'].replace('ca', 'Canada')
df['region'] = df['region'].replace('us', 'USA')
df['region'] = df['region'].replace('de', 'Germany')
df['region'] = df['region'].replace('fr', 'France')
df['region'] = df['region'].replace('mx', 'Mexico')
df['region'] = df['region'].replace('nl', 'Netherlands')
df['region'] = df['region'].replace('se', 'Sweden')
df['region'] = df['region'].replace('gb', 'UK')

# %%
# saving clean data into new csv file to be used for modeling 
df.to_csv('..//data/df.csv', index = False)

# %%
# Change date column to be datetime dtype
df.set_index(pd.to_datetime(df['date']), inplace = True)

# %%
df.drop(columns =['date'], inplace = True)

# %%
df.sort_index(inplace = True)

# %%
df.reset_index
df.head()
# Out:
#             Position                                     Track Name  \
# date
# 2019-01-01         1  Sunflower - Spider-Man: Into the Spider-Verse
# 2019-01-01         2                                           Wow.
# 2019-01-01         3                                     SICKO MODE
# 2019-01-01         4                                  thank u, next
# 2019-01-01         5                        Going Bad (feat. Drake)
#
#                    Artist    Streams region              spotify_id
# date
# 2019-01-01    Post Malone  1867789.0    USA  3KkXRkHbMCARz0aVfEt68P
# 2019-01-01    Post Malone  1564946.0    USA  6MWtB6iiXyIwun0YzU6DFP
# 2019-01-01   Travis Scott  1454622.0    USA  2xLMifQCjDGFmkHkpNLD9h
# 2019-01-01  Ariana Grande  1397512.0    USA  2rPE9A1vEgShuZxxzR2tZH
# 2019-01-01      Meek Mill  1245437.0    USA  2IRZnDFmlqMuOrYOLnZZyc

# %% [markdown]
# ### EDA

# %%
# Total number of unique artists, songs and streams 
print('Total number of artists:', len(df['Artist'].unique()))
print('Total number of songs:', len(df['Track Name'].unique()))
print('Total number of Streams:', df['Streams'].sum())
# Out:
# Total number of artists: 2574
# Total number of songs: 8826
# Total number of Streams: 88609758967.0

# %%
# Plotting Streaming trend overtime 
df['Streams'].plot(figsize=(8, 4), 
                     color='sienna', zorder=2)
plt.title("Streams over time",fontweight="bold");               
plt.xlabel("", fontsize = 10)
plt.ylabel("Streams", fontsize = 14);

# %%
# plotting average stream 
avg_stream = df.groupby('region')['Streams'].mean() # look into avg sterams by region
avg_stream.plot(kind = 'bar', figsize=(8, 4), 
                     color='olive', zorder=2, 
                    width=0.85)
plt.title("Average Streams by Top 10 Markets",fontweight="bold");               
plt.xlabel("", fontsize = 12)
plt.ylabel("Streams", fontsize = 14);

# %%
top_artists = rank.groupby('Artist')["Streams"].sum(ascending = False).head(10)
top_artists.plot(kind = 'barh')

# %%
rank1_mask = df[df['Position']== 1] # creating mask for rank1

# %%
#top_artists = rank1_mask['Artist'].sum(ascending = False).head(10) # Look into rank1 artists
top_artist = rank1_mask.groupby('Artist')['Streams'].value_counts(ascending = False).head(10)
top_artist.plot(kind = 'barh');

# %%
top_tracks = rank1_mask['Track Name']['Streams'].value_counts(ascending = False).head(10) # look into rank 1 songs
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    4735             try:
# -> 4736                 return libindex.get_value_box(s, key)
#    4737             except IndexError:
#
# pandas/_libs/index.pyx in pandas._libs.index.get_value_box()
#
# pandas/_libs/index.pyx in pandas._libs.index.get_value_at()
#
# pandas/_libs/util.pxd in pandas._libs.util.get_value_at()
#
# pandas/_libs/util.pxd in pandas._libs.util.validate_indexer()
#
# TypeError: 'str' object cannot be interpreted as an integer
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/datetimes.py in get_value(self, series, key)
#     992         try:
# ...

# %%
ax = top_artists.plot(kind = 'barh', figsize=(8, 5), 
                     color='darkturquoise', zorder=2, 
                        width=0.85)
plt.title("Top Artists 2019", fontweight = 'bold')
ax.invert_yaxis();

# %%
ax = top_tracks.plot(kind = 'barh', figsize=(8, 5), 
                     color='darkturquoise', zorder=2, 
                        width=0.85)
plt.title("Top Tracks 2019", fontweight = 'bold')
ax.invert_yaxis();

# %%
top_singers_byreg = df[df['Position']==1].groupby('region')['Artist'].value_counts()

# %%
#df[df['Position']==1]['Streams'].groupby(df['Artist']).sum().sort_values(ascending = False)

# %%
# how can I make counts based on # of Streams?

df[df['Position']==1]['Artist'].value_counts()

# %%
top_singers_byreg

# %%
top_songs_byreg = df[df['Position']==1].groupby('region')['Track Name'].value_counts()
top_songs_byreg
# Out:
# region     Track Name
# Australia  Dance Monkey                         135
#            7 rings                               50
#            bad guy                               47
#            I Don't Care (with Justin Bieber)     39
#            Señorita                              36
#                                                ...
# USA        Panini                                 2
#            Adore You                              1
#            BOP                                    1
#            You Need To Calm Down                  1
#            boyfriend (with Social House)          1
# Name: Track Name, Length: 230, dtype: int64

# %%
top_songs_byreg

# %%
df.drop(columns =['date'], inplace = True)

# %%
def plot_series(df, cols=None, title='Title', xlab=None, ylab=None, steps=1):
    
    
    plt.figure(figsize=(18,9))
    for col in cols:
        plt.plot(df[col])
    
    plt.title(title, fontsize=26)
    plt.xlabel(xlab, fontsize=20)
    plt.ylabel(ylab, fontsize=20)
    plt.yticks(fontsize=18)
    plt.xticks(df.index[0::steps], fontsize=18);

# %%
plot_series(df['spotify_id'] == '7KPGeiXWDsGEvFK62wzU8E'], cols=['Position'], title = '888', steps = 12)
inves
# Out:
#   File "<ipython-input-236-32e1521acf6d>", line 1
#     plot_series(df['spotify_id'] == '7KPGeiXWDsGEvFK62wzU8E'], cols=['Position'], title = '888', steps = 12)
#                                                             ^
# SyntaxError: invalid syntax

# %%
# Creating segments for top ranked songs to be used for daily forecast to predict duration a song resist 
rank1_mask = df[df['Position']== 1] 
rank_one = rank1_mask.groupby('Track Name')['Streams'].unique()

# %%
#cross checking for US top ranking artists 
#df_regionalnew[df_regionalnew['region'] == 'USA'].sort_values('top_rank')['Artist'].unique()

# %%
data = df[['Streams', 'Position']]
km = KMeans(n_clusters=10)
km.fit(data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-147-c466d67dfda5> in <module>
#       1 data = df[['Streams', 'Position']]
# ----> 2 km = KMeans(n_clusters=10)
#       3 km.fit(data)
#
# NameError: name 'KMeans' is not defined

# %%
lt.figure(figsize=(7,5))
plt.scatter(df.Position, df.Streams, c=km.labels_, s=1, cmap="tab20");
plt.title('Ranks by Streams');
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-148-89ae86bdaa1a> in <module>
# ----> 1 lt.figure(figsize=(7,5))
#       2 plt.scatter(df.Position, df.Streams, c=km.labels_, s=1, cmap="tab20");
#       3 plt.title('Ranks by Streams');
#
# NameError: name 'lt' is not defined

# %%
#germany_df.pivot(index='date', columns='Position', values='Streams')
