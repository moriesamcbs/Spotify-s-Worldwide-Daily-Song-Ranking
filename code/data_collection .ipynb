# %%
import requests
import pandas as pd
import re
from bs4 import BeautifulSoup

# %% [markdown]
# # EXTRACTING DATA FROM SPOTIFY

# %% [markdown]
# ### Getting all the data from Spotify Charts

# %%
#spotify_url = 'https://spotifycharts.com/regional'
#spotify =[]

#res4 = requests.get(spotify_url)
#soup = BeautifulSoup(res4.content, 'html.parser')

#spotify_track = []
#for t in soup.find('body').find_all('tr')[1:]:
    #q = t.find('td', {'class' : 'chart-table-track'})
    #song = q.find('strong')
    #artist = q.find('span')
    #song_dict = {'song' : song.text, 'album/artist' : artist.text}
    #spotify_track.append(song_dict)
#spotify = pd.DataFrame(spotify_track)

# %%
#spotify['album/artist'].value_counts()
# Out:
# by Billie Eilish    10
# by Ed Sheeran        6
# by Post Malone       6
# by Harry Styles      4
# by Travis Scott      4
#                     ..
# by Nicki Minaj       1
# by Lady Gaga         1
# by Samra             1
# by Trevor Daniel     1
# by G-Eazy            1
# Name: album/artist, Length: 121, dtype: int64

# %%
#spotify_url = 'https://spotifycharts.com/regional/us/daily'
#spotify =[]

#res4 = requests.get(spotify_url)
#soup = BeautifulSoup(res4.content, 'html.parser')

#spotify_track = []
#for t in soup.find('body').find_all('tr')[1:]:
    #q = t.find('td', {'class' : 'chart-table-track'})
    #song = q.find('strong')
    #artist = q.find('span')
    
    #song_dict = {'song' : song.text, 'album/artist' : artist.text}
    #spotify_track.append(song_dict)
#spotify = pd.DataFrame(spotify_track)

# %%
from fycharts.SpotifyCharts import SpotifyCharts
api = SpotifyCharts()

# %%
api.top200Daily(output_file='top200-new.csv', start="2019-01-01", end="2019-12-31", 
                region=['us','gb', 'de', 'br', 'mx', 'ca', 'au', 'nl', 'fr', 'se'])
# Out:
# INFO : 14/02/2020 12:41:11 PM : Extracting top 200 daily for 2019-01-01 - us
# INFO : 14/02/2020 12:41:12 PM : Extracting top 200 daily for 2019-01-01 - gb
# INFO : 14/02/2020 12:41:12 PM : Appending data to the file top200-new.csv...
# INFO : 14/02/2020 12:41:12 PM : Done appending to the file top200-new.csv!!!
# INFO : 14/02/2020 12:41:14 PM : Extracting top 200 daily for 2019-01-01 - de
# INFO : 14/02/2020 12:41:14 PM : Appending data to the file top200-new.csv...
# INFO : 14/02/2020 12:41:14 PM : Done appending to the file top200-new.csv!!!
# INFO : 14/02/2020 12:41:14 PM : Extracting top 200 daily for 2019-01-01 - br
# INFO : 14/02/2020 12:41:14 PM : Appending data to the file top200-new.csv...
# INFO : 14/02/2020 12:41:14 PM : Done appending to the file top200-new.csv!!!
# INFO : 14/02/2020 12:41:15 PM : Extracting top 200 daily for 2019-01-01 - mx
# INFO : 14/02/2020 12:41:15 PM : Appending data to the file top200-new.csv...
# ...
